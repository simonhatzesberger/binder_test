# %% [markdown]
# <img style="float:center; width:250px; margin-top: 15px; margin-bottom: 15px" src="data:image/jpeg;base64,..." />

# %% [markdown]
# <p style="font-size:19px; text-align:left; margin-top: 15px; margin-bottom: 5px">Working Group <i>Explainable Artificial Intelligence</i></p>
# <p style="font-size:25px; text-align:left; margin-bottom: 15px"><b>On Model-Agnostic Explainability Methods for Regression Problems</b></p>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">1. Introduction</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">2. Analysis and Preprocessing of the Underlying Dataset</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <img style="float:center; width:500px; margin-top: 15px; margin-bottom: 15px" src="data:image/jpeg;base64,..."/>

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

df_raw = fetch_openml("Bike_Sharing_Demand", version=2, as_frame=True)
X, y = df_raw.data.copy(), df_raw.target

# print first 10 rows of the Bike Sharing dataset
pd.concat([X, y], axis=1).head(10)
# Out:
#    season  year  month  hour holiday  weekday workingday weather   temp  \
# 0  spring   0.0    1.0   0.0   False      6.0      False   clear   9.84
# 1  spring   0.0    1.0   1.0   False      6.0      False   clear   9.02
# 2  spring   0.0    1.0   2.0   False      6.0      False   clear   9.02
# 3  spring   0.0    1.0   3.0   False      6.0      False   clear   9.84
# 4  spring   0.0    1.0   4.0   False      6.0      False   clear   9.84
# 5  spring   0.0    1.0   5.0   False      6.0      False   misty   9.84
# 6  spring   0.0    1.0   6.0   False      6.0      False   clear   9.02
# 7  spring   0.0    1.0   7.0   False      6.0      False   clear   8.20
# 8  spring   0.0    1.0   8.0   False      6.0      False   clear   9.84
# 9  spring   0.0    1.0   9.0   False      6.0      False   clear  13.12
#
#    feel_temp  humidity  windspeed  count
# 0     14.395      0.81     0.0000   16.0
# 1     13.635      0.80     0.0000   40.0
# 2     13.635      0.80     0.0000   32.0
# ...

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">3. Fitting of Machine Learning Models</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">4. Global Model-Agnostic Methods</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">4.1 Partial Dependence Plot (PDP)</h2>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">4.2 Global Surrogate Model</h2>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">4.3 Accumulated Local Effects (ALE)</h2>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">5. Local Model-Agnostic Methods</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">5.1 Shapley Additive Explanations (SHAP)</h2>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">5.2 Local Interpretable Model-agnostic Explanations (LIME)</h2>

# %% [markdown]
# <h2 style="font-size:16px; font-weight:bold; font-style:italic; margin-top: 15px; margin-bottom: 15px;">5.3 Individual Conditional Expectation (ICE)</h2>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">6. Conclusion</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">Appendix: Didactically Refined Program Code of Selected Methods</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>

# %% [markdown]
# <h1 style="font-size:18px; font-weight:bold; margin-top: 15px;">References</h1>
# <hr style="border:1.5px solid black; margin-bottom: 15px;"> </hr>
